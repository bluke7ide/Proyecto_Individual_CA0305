# %%
from Bingo import Bingo
import random as rd
rd.seed(16)
juego = Bingo(32,75,["Horizontal", "Vertical", "Diagonal"])
juego.construir()

# %%
for i in range(32):
    print(f"Tablero {i+1}")
    print(juego.tableros[i].tablero)
# Out:
# Tablero 1
# [[ 6 23 42 50 72]
#  [ 8 16 35 59 70]
#  [ 5 22  0 51 65]
#  [ 7 29 41 56 61]
#  [ 4 26 31 48 73]]
# Tablero 2
# [[ 4 18 38 49 73]
#  [10 28 40 58 62]
#  [ 5 25  0 50 66]
#  [ 1 26 42 51 68]
#  [15 16 35 52 67]]
# Tablero 3
# [[ 9 25 43 53 63]
#  [11 16 31 48 72]
#  [ 3 20  0 50 68]
#  [10 17 36 51 74]
#  [ 5 29 34 47 61]]
# Tablero 4
# [[ 8 28 32 57 61]
#  [14 17 38 49 69]
#  [ 1 23  0 60 71]
#  [15 29 31 52 67]
#  [12 25 33 51 70]]
# Tablero 5
# [[ 6 28 36 46 62]
#  [ 8 26 32 52 72]
#  [ 9 29  0 56 71]
#  [11 17 39 60 61]
#  [14 19 34 59 74]]
# Tablero 6
# [[13 27 31 47 67]
#  [ 7 20 34 56 61]
#  [ 3 19  0 48 68]
#  [15 18 45 50 75]
#  [11 25 32 52 72]]
# Tablero 7
# [[ 8 22 37 47 74]
#  [ 5 26 32 50 67]
#  [ 1 20  0 53 64]
#  [12 30 34 52 63]
#  [ 4 24 41 48 75]]
# Tablero 8
# [[ 3 22 44 52 70]
#  [15 18 33 59 65]
#  [ 7 21  0 46 62]
#  [ 9 26 34 53 74]
#  [ 4 23 41 50 73]]
# Tablero 9
# [[13 24 38 56 68]
#  [ 5 26 39 47 62]
#  [12 23  0 57 73]
#  [ 8 19 32 51 72]
# ...

# %%
juego.num()
juego.revisar(True)
juego.salidos
# Out:
# El tablero 1 ganó por la combinación Vertical
# El tablero 26 ganó por la combinación Vertical
# [1, 2, 3, 4, 5, 6, 7, 8]
